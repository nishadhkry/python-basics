# %% [markdown]
# day 1 collection

# %%
print("hello world")
# Out:
# hello world

# %%
print('it's a rainy day "wednesday"')
# Out:
#   Cell In[3], line 1
#     print('it's a rainy day "wednesday"')
#                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %% [markdown]
# collection in python

# %% [markdown]
# way to store multiple values in a single way

# %% [markdown]
# list - collection of multiple value stored in order and it is changable /mutable it allows duplicate

# %%
number=[10,20,30,40]
print(number[0]) #indexing
# Out:
# 10

# %% [markdown]
# modify list

# %%
number[1]=25
print(number)
# Out:
# [10, 25, 30, 40]

# %% [markdown]
# add an element

# %%
#append
number.append(50)

# %%
print(number)
# Out:
# [10, 25, 30, 40, 50]

# %%
numbers=[10,20,30,40,50]
numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
data=[10,"nisha",3.5,True]
print(data)
# Out:
# [10, 'nisha', 3.5, True]

# %%
numbers[0]
# Out:
# 10

# %%
numbers[2]
# Out:
# 30

# %%
numbers[3]
# Out:
# 40

# %% [markdown]
# length of the list

# %%
len(numbers)
# Out:
# 5

# %% [markdown]
# index starts from zero and length starts from 1

# %%
sum(numbers)#add all elements of listmax(numbers)
# Out:
# 150

# %%
max(numbers)
# Out:
# 50

# %%
min(numbers)
# Out:
# 10

# %%
names=["A","B","Z"]
max(names)
# Out:
# 'Z'

# %% [markdown]
# add or remove elements

# %%
#for add element we use -append(),adss value at the end of the list
numbers.append(60)
# Out:
# [10, 20, 30, 40, 50, 60, 60, 60, 60]

# %%
print(numbers)
# Out:
# [10, 20, 30, 40, 50, 60, 60, 60, 60]

# %%
#remove element -pop(),removes the last element by default
numbers.pop()
print(numbers)
# Out:
# [10, 40, 50, 60, 60]

# %%
numbers.pop(1)
# Out:
# 30

# %%
print(numbers)
# Out:
# [10, 40, 50, 60, 60, 60]

# %%
#difference between append and insert
#append will add at the end and insert will add at any specific position
#list slicing
#start:end -start index will get include,end index will get exclude 
numbers=[10,20,30,40,50]
numbers[1:4]
# Out:
# [20, 30, 40]

# %%
#last three elements(negative indexing)
#last element is -1 and second last is -2 and so on.
numbers[-3:]
# Out:
# [30, 40, 50]

# %%
numbers[-1]
# Out:
# 50

# %%
data=[5,10,15,20] #find last element
data[-1]
# Out:
# 20

# %%
# add 25 to the list and print
data.append(25)

# %%
print(data)
# Out:
# [5, 10, 15, 20, 25, 25, 25]

# %%
#get first three element using slicing
data[0:3 #start:end --this is list slicing where starts gets included and end is excluded
# Out:
# [5, 10, 15]

# %%
names=["A","Z","B"]
max(names)#it does alphabetical comparision not numerical for an example A-65,B-66 AND Z-90
# Out:
# 'Z'

# %%
fruits=["apple","banana","cherry"]
max(fruits)#a-97 ASCII value ,b-98 ,c-99
#python compares strings character by character from left to right
# Out:
# 'cherry'

# %%
words=["bat","ball"]
max(words)
# Out:
# 'bat'

# %%
min(names)
# Out:
# 'A'

# %% [markdown]
# tuple

# %%
my_tuple=(10,20,30,40,50)
my_tuple
# Out:
# (10, 20, 30, 40, 50)

# %%
#tuple uses round brackets 
#tuple is immutable-once it is created we cannot change its value
#it has ordered sequence same as list it aslo has an index
#but memories is fixed because we cannot modify it

# %%
my_tuple[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 my_tuple[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#mix datatypes
datas=(12,"nisha",2.7,False)
print(datas)
# Out:
# (12, 'nisha', 2.7, False)

# %%
#tuple slicing
my_tuple[1:4]
# Out:
# (20, 30, 40)

# %%
#slicing return same datatypes as original

# %%
my_tuple[-3:]
# Out:
# (30, 40, 50)

# %%
# negative-when we want last elements without knowing list/tuple size

# %% [markdown]
# zip function-it combines multiple collection into pairs,it groups element based on index position

# %%
coders=["nisha","ishwor","matrika","nick","bipina"]
marks=[50,60,27,90,95]

list(zip(coders,marks))
# Out:
# [('nisha', 50), ('ishwor', 60), ('matrika', 27), ('nick', 90), ('bipina', 95)]

# %%
#index wise mappping 
#index 0 - nisha+ 50 
#zip returns zip object not a list

# %%
zip(coders,marks)

# %%
alphabet=["A","B","C"]
num=[80,90]
list(zip(alphabet,num))
# Out:
# [('A', 80), ('B', 90)]

# %%
#zip stops at the shortest list

# %%
#create a list , find the length of the list, add 2-elements in the list
n=[10,20,"nisha",2.5,88]
print(n)
# Out:
# [10, 20, 'nisha', 2.5, 88]

# %%
len(n)
# Out:
# 5

# %%
n.append("adhikari")
print(n)
# Out:
# [10, 20, 'nisha', 2.5, 88, 'adhikari', 'adhikari', 'adhikari', 'adhikari']

# %%
n.append(18)
print(n)
# Out:
# [10, 20, 'nisha', 2.5, 88, 'adhikari', 'adhikari', 'adhikari', 'adhikari', 18]

# %%
#create a tuple ,perform slicing , to get the subset of the tuple
nisha_tuple=(10,30,50,70,90)
subset = my_tuple[1:4]
print(subset)
# Out:
# (20, 30, 40)

# %%
#From beginning to index 3
print(nisha_tuple[:3])
# Out:
# (10, 30, 50)

# %%
#From index 2 to end
print(nisha_tuple[2:])
# Out:
# (50, 70, 90)

# %%
#Every 2nd element (step slicing)
print(nisha_tuple[::2])
# Out:
# (10, 50, 90)

# %%
#perform zip function from two list and result should be in list
a=[10,30,40,50]
b=["kathmandu","usa","canada","india"]
list(zip(b,a))#zip returns tuple as each pair store as an immutable record(tuple)
# Out:
# [('kathmandu', 10), ('usa', 30), ('canada', 40), ('india', 50)]

# %%
coders=[('kathmandu', 10), ('usa', 30), ('canada', 40), ('india', 50)]
a,b=zip(*coders)
print(a)
print(b)
# Out:
# ('kathmandu', 'usa', 'canada', 'india')
# (10, 30, 40, 50)

# %%
scores=[10,30,40,50]
students=["kathmandu","usa","canada","india"]
for name,score in zip(students,scores):
 print(name,score)
# Out:
# kathmandu 10
# usa 30
# canada 40
# india 50

# %%
A=[1,2,3]
B=[3,4,5]
C=[4,5,6]
list(zip(A,B,C))#ZIP CAN TAKE MORE THAN TWO LIST
# Out:
# [(1, 3, 4), (2, 4, 5), (3, 5, 6)]

# %% [markdown]
# SET

# %%
my_set={1,2,2,3,4,5,6,3,4}
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set.add(7)
print(my_set)#insert a new element into a set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
my_set.add(3)
print(my_set)#if value exist already and you try to add then it simply ignore /no duplicate added
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
my_set.remove(1)
print(my_set)#remove()deletes a specific elements from a set
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
my_set.remove(8)
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 my_set.remove(8)
#       2 print(my_set)
#
# KeyError: 8

# %%
my_set.discard(8)#using discard we will get no key error but shows the set
print(my_set)
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
len(my_set)#returns the number of unique elements
# Out:
# 6

# %%
min(my_set)
# Out:
# 2

# %%
max(my_set)
# Out:
# 7

# %%
sum(my_set)#adds elements in the list
# Out:
# 27

# %% [markdown]
# union in set
# union combines all unique values from both the sets

# %%
aa={1,2,3}
bb={3,4,5}
aa|bb #union
aa&bb #intersection(common element from both tht set)
aa-bb #difference gives elements in first set but not in second set
bb-aa
# Out:
# {4, 5}

# %%
#symmetric difference ^
aa^bb #elements present in either set but not both
# Out:
# {1, 2, 4, 5}

# %%
#remove duplicate from list
pages=[1,2,2,3,4,4,5,6]

my_pages=set(pages)
my_pages
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_pages[0] #sets are unordered
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 my_pages[0]
#
# TypeError: 'set' object is not subscriptable

# %%
coders={[1,2],[3,4]} #we cannot store list inside set,list are mutable and it is not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 coders={[1,2],[3,4]}
#
# TypeError: unhashable type: 'list'

# %%
code={(1,2),(3,4)} #tuples are allowed because they are imutable
code
# Out:
# {(1, 2), (3, 4)}

# %%
#whenever we need unique values or comparision between data sets are the good

# %%
datas=[1,2,2,3,4,4,5]
data=set(datas) #convert list to set and remove duplicate
print(data)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set=[1,2,3]
new_set=set(my_set)
new_set.add(10)
print(new_set)
# Out:
# {10, 1, 2, 3}

# %%
#remove element safely
my_set={1,2,3}
my_set.discard(5)#it doesnot throw error if element not present
my_set
# Out:
# {1, 2, 3}

# %%
#common element
AA={1,2,3,4}
BB={3,4,5,6}
AA|BB 
AA&BB
AA^BB
# Out:
# {1, 2, 5, 6}

# %%
my_list = [1, 2, 2, 3, 4, 4, 5]

unique_list= len(set(my_list))#converted list into set to remove duplicate,len to count the element
unique_list
# Out:
# 5

# %%
my_set = {1, 2, 3, 4, 5}

print (3 in my_set)#in -checks memberships,very fast in sets,return boolean value
print (6 in my_set)
# Out:
# True
# False

# %%
my_set = {1, 2, 3, 4, 5}
my_list = list(my_set)
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# dictionary

# %%
this_dict={
    "name" : "nisha",
    "year":2026,
    "year":2020,
    "class": "BDE"}
print(this_dict) #duplicate values will overwrite existing values
# Out:
# {'name': 'nisha', 'year': 2020, 'class': 'BDE'}

# %%
print(this_dict["name"])
# Out:
# nisha

# %%
student={
    "name":"nisha",
    "year":2025,
    "course" :"DE"}
print(student)
# Out:
# {'name': 'nisha', 'year': 2025, 'course': 'DE'}

# %%
# A KEY-LIKE LABEL OR NAME USED TO IDENTIFY THE DATA
student["name"]
#use the key inside square bracket to get the value
# Out:
# 'nisha'

# %%
student["year"]
# Out:
# 2025

# %%
student["course"]
# Out:
# 'DE'

# %%
student["city"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 student["city"]
#
# KeyError: 'city'

# %%
student.get("city")
print(student.get("city"))#this is the safe way to check if any item present in dictionary or not
# Out:
# None

# %%
student.pop("year") #pop removes the keyvalue pair using the key
# Out:
# 2025

# %%
print(student)
# Out:
# {'name': 'nisha', 'course': 'DE'}

# %%
student.pop("salary","not found")
# Out:
# 'DE'

# %%
#length of the dictionary
len(student) # it gives numbers of keys and value pairs,len function counts pairs(key+value)
# Out:
# 1

# %%
student
# Out:
# {'name': 'nisha'}

# %%
student.clear()#clear removes everything from the dictionary,dict becomes empty but variable still exists

# %%
print(student)
# Out:
# {}

# %%
student={}
student["name"]="arbin"
student["year"]=2020
student #we can add values using the keys
# Out:
# {'name': 'arbin', 'year': 2020}

# %%
student["year"]=2025 #update value
student
# Out:
# {'name': 'arbin', 'year': 2025}

# %%
#important properties
dict={
    "name":"nisha",
    "name":"ayush" #last value will get overwrites
}
dict
# Out:
# {'name': 'ayush'}

# %%
#values can be duplicates
data1={
    "a":10,
    "b":10
}
data1
# Out:
# {'a': 10, 'b': 10}

# %%
employee={
    "id":12,
    "name":"nisha",
    "salary":35000
}
employee["name"]
# Out:
# 'nisha'

# %%
data={
    1:"one"
}

# %%
data
# Out:
# {1: 'one'}

# %%
## Keys should be immutable, so we can not assign any mutable collection or data structure as a key in a dict
my_data={
    [1,2]:"value"
    
}
print(my_data[1,2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## Keys should be immutable, so we can not assign any mutable collection or data structure as a key in a dict
# ----> 2 my_data={
#       3     [1,2]:"value"
#       4
#       5 }
#       6 print(my_data[1,2])
#
# TypeError: unhashable type: 'list'

# %%
#keys can be number,yes you can assign numbers as keys
my_data={
    1:"one",
    2:"two"
}
print(my_data[1])
# Out:
# one

# %%
text="nisha"
my_text="nisha11"
my_text1=""
my_text2="hii coders"
my_text3="hello!"
print(my_text.isalpha())
print(my_text1.isalpha())
print(my_text2.isalpha())
print(my_text3.isalpha())
# Out:
# False
# False
# False
# False

# %%
#fromkeys() method returns dict with specified keys or values
x=('key1','key2','key3')
y=0
this_dict=dict.fromkeys(x,y)
print(this_dict)
# Out:
# {'key1': 0, 'key2': 0, 'key3': 0}

# %%
#loops in dictionary-for loop
employee={
    "id":12,
    "name":"nisha",
    "salary":35000
}
print(employee)
# Out:
# {'id': 12, 'name': 'nisha', 'salary': 35000}

# %%
for x in employee:
    print(employee[x])
# Out:
# 12
# nisha
# 35000

# %%
for x in employee.items():
    print(x)
# Out:
# ('id', 12)
# ('name', 'nisha')
# ('salary', 35000)

# %%
for x in employee.keys():
    print(x)
# Out:
# id
# name
# salary

# %%
for x in employee.values():
    print(x)
# Out:
# 12
# nisha
# 35000
